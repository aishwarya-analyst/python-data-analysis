# %%
import numpy as np
import pandas as pd

# %%
myindex=['kolar','bgl','mysore','bsk']
mydata=[100,200,300,400]

# %%
myser=pd.Series(data=myindex,index=mydata)
myser
# Out:
# 100     kolar
# 200       bgl
# 300    mysore
# 400       bsk
# dtype: object

# %%
myser1=pd.Series(myindex,index=mydata)
myser1
# Out:
# 100     kolar
# 200       bgl
# 300    mysore
# 400       bsk
# dtype: object

# %%
rand_data=np.random.randint(0,100,4)
rand_data
# Out:
# array([ 0, 73, 20, 51], dtype=int32)

# %%
names=['A','B','C','D']
ages=pd.Series(names,rand_data)
ages
# Out:
# 0     A
# 73    B
# 20    C
# 51    D
# dtype: object

# %%
ages=pd.Series(rand_data,names)
ages
# Out:
# A     0
# B    73
# C    20
# D    51
# dtype: int32

# %%
import pandas as pd
orders=pd.read_table('http://bit.ly//chiporders')
orders.head(2)
# Out:
#    order_id  quantity                     item_name choice_description  \
# 0         1         1  Chips and Fresh Tomato Salsa                NaN
# 1         1         1                          Izze       [Clementine]
#
#   item_price
# 0     $2.39
# 1     $3.39

# %%
user_cols=['id','age','gender','work','salary']
movies=pd.read_table('http://bit.ly//movieusers',sep='|',header=None,names=user_cols)
movies.head()
# Out:
#    id  age gender        work salary
# 0   1   24      M  technician  85711
# 1   2   53      F       other  94043
# 2   3   23      M      writer  32067
# 3   4   24      M  technician  43537
# 4   5   33      F       other  15213

# %%
ufo=pd.read_table('http://bit.ly//uforeports',sep=',')
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo=pd.read_csv('http://bit.ly//uforeports')
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo[['City','Colors Reported','Time']].head()
# Out:
#                    City Colors Reported             Time
# 0                Ithaca             NaN   6/1/1930 22:00
# 1           Willingboro             NaN  6/30/1930 20:00
# 2               Holyoke             NaN  2/15/1931 14:00
# 3               Abilene             NaN   6/1/1931 13:00
# 4  New York Worlds Fair             NaN  4/18/1933 19:00

# %%
ufo1=ufo.City
type(ufo1)
ufo1.head()
# Out:
# 0                  Ithaca
# 1             Willingboro
# 2                 Holyoke
# 3                 Abilene
# 4    New York Worlds Fair
# Name: City, dtype: object

# %%
ufo1=ufo[['City']]
type(ufo1)
ufo1.head()
# Out:
#                    City
# 0                Ithaca
# 1           Willingboro
# 2               Holyoke
# 3               Abilene
# 4  New York Worlds Fair

# %%
ufo['location']=ufo.City+','+ufo.State
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time  \
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00
#
#                   location
# 0                Ithaca,NY
# 1           Willingboro,NJ
# 2               Holyoke,CO
# 3               Abilene,KS
# 4  New York Worlds Fair,NY

# %%
import pandas as pd
ufo=pd.read_csv('http://bit.ly//uforeports')
ufo['location'],ufo['timessss']=[ufo.City+'**'+ufo.State,ufo['Time']]

# %%
movies=pd.read_csv('http://bit.ly//imdbratings')
m1=movies[2:100]
m1
# Out:
#     star_rating                           title content_rating      genre  \
# 2           9.1          The Godfather: Part II              R      Crime
# 3           9.0                 The Dark Knight          PG-13     Action
# 4           8.9                    Pulp Fiction              R      Crime
# 5           8.9                    12 Angry Men      NOT RATED      Drama
# 6           8.9  The Good, the Bad and the Ugly      NOT RATED    Western
# ..          ...                             ...            ...        ...
# 95          8.4                   All About Eve       APPROVED      Drama
# 96          8.4                         Yojimbo        UNRATED     Action
# 97          8.4                       The Sting             PG     Comedy
# 98          8.4                        Rashomon        UNRATED      Crime
# 99          8.4                         Amadeus              R  Biography
#
#     duration                                        actors_list
# ...

# %%
m1.describe()
# Out:
#        star_rating    duration
# count     98.00000   98.000000
# mean       8.54898  134.438776
# std        0.16699   32.407542
# min        8.40000   68.000000
# 25%        8.40000  110.500000
# 50%        8.50000  129.500000
# 75%        8.60000  154.750000
# max        9.10000  229.000000

# %%
#movies.genre.describe()
movies[['genre']].describe()
# Out:
#         genre
# count     979
# unique     16
# top     Drama
# freq      278

# %%
movies.describe(include=['object'])
# Out:
#           title content_rating  genre  \
# count       979            976    979
# unique      975             12     16
# top     Dracula              R  Drama
# freq          2            460    278
#
#                                               actors_list
# count                                                 979
# unique                                                969
# top     [u'Daniel Radcliffe', u'Emma Watson', u'Rupert...
# freq                                                    6

# %%
movies.shape
# Out:
# (979, 6)

# %%
ufo=pd.read_csv('http://bit.ly//uforeports')
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo.columns
# Out:
# Index(['City', 'Colors Reported', 'Shape Reported', 'State', 'Time'], dtype='object')

# %%
ufo.rename(columns={'Colors Reported':'colors_reported','Time':'date_Time'},inplace=True)
ufo.head()
# Out:
#                    City colors_reported Shape Reported State        date_Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo_cols=['cityzzz','colors','shapes','ssstate','datessss']
ufo.columns=ufo_cols
ufo.head()
# Out:
#                 cityzzz colors    shapes ssstate         datessss
# 0                Ithaca    NaN  TRIANGLE      NY   6/1/1930 22:00
# 1           Willingboro    NaN     OTHER      NJ  6/30/1930 20:00
# 2               Holyoke    NaN      OVAL      CO  2/15/1931 14:00
# 3               Abilene    NaN      DISK      KS   6/1/1931 13:00
# 4  New York Worlds Fair    NaN     LIGHT      NY  4/18/1933 19:00

# %%
import pandas as pd
ufo=pd.read_csv('http://bit.ly//uforeports')
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo.drop('City',axis=1,inplace=True)
ufo.head()
# Out:
#   Colors Reported Shape Reported State             Time
# 0             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1             NaN          OTHER    NJ  6/30/1930 20:00
# 2             NaN           OVAL    CO  2/15/1931 14:00
# 3             NaN           DISK    KS   6/1/1931 13:00
# 4             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo.drop(['Colors Reported','State'],axis=1,inplace=True)
ufo.head()
# Out:
#   Shape Reported             Time
# 0       TRIANGLE   6/1/1930 22:00
# 1          OTHER  6/30/1930 20:00
# 2           OVAL  2/15/1931 14:00
# 3           DISK   6/1/1931 13:00
# 4          LIGHT  4/18/1933 19:00

# %%
ufo.drop([0,1],axis=0,inplace=True)
ufo.head()
# Out:
#   Shape Reported             Time
# 2           OVAL  2/15/1931 14:00
# 3           DISK   6/1/1931 13:00
# 4          LIGHT  4/18/1933 19:00
# 5           DISK  9/15/1934 15:30
# 6         CIRCLE   6/15/1935 0:00

# %%
movies=pd.read_csv('http://bit.ly//imdbratings')
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies.title.sort_values().head(20)
# Out:
# 542            (500) Days of Summer
# 5                      12 Angry Men
# 201                12 Years a Slave
# 698                       127 Hours
# 110           2001: A Space Odyssey
# 910                            2046
# 596                        21 Grams
# 624                       25th Hour
# 708                28 Days Later...
# 60                         3 Idiots
# 225                          3-Iron
# 570                             300
# 555                    3:10 to Yuma
# 427    4 Months, 3 Weeks and 2 Days
# 824                              42
# 597                           50/50
# 203                           8 1/2
# 170                A Beautiful Mind
# 941                A Bridge Too Far
# 571                    A Bronx Tale
# Name: title, dtype: object

# %%
movies.title.sort_values(ascending=False).head()
# Out:
# 864               [Rec]
# 526                Zulu
# 615          Zombieland
# 677              Zodiac
# 955    Zero Dark Thirty
# Name: title, dtype: object

# %%
movies.sort_values('title',ascending=False).head()
# Out:
#      star_rating             title content_rating   genre  duration  \
# 864          7.5             [Rec]              R  Horror        78
# 526          7.8              Zulu        UNRATED   Drama       138
# 615          7.7        Zombieland              R  Comedy        88
# 677          7.7            Zodiac              R   Crime       157
# 955          7.4  Zero Dark Thirty              R   Drama       157
#
#                                            actors_list
# 864  [u'Manuela Velasco', u'Ferran Terraza', u'Jorg...
# 526  [u'Stanley Baker', u'Jack Hawkins', u'Ulla Jac...
# 615  [u'Jesse Eisenberg', u'Emma Stone', u'Woody Ha...
# 677  [u'Jake Gyllenhaal', u'Robert Downey Jr.', u'M...
# 955  [u'Jessica Chastain', u'Joel Edgerton', u'Chri...

# %%
movies.sort_values(['duration','star_rating'],ascending=False).head()
# Out:
#      star_rating                              title content_rating      genre  \
# 476          7.8                             Hamlet          PG-13      Drama
# 157          8.2                 Gone with the Wind              G      Drama
# 78           8.4        Once Upon a Time in America              R      Crime
# 142          8.3  Lagaan: Once Upon a Time in India             PG  Adventure
# 445          7.9               The Ten Commandments       APPROVED  Adventure
#
#      duration                                        actors_list
# 476       242  [u'Kenneth Branagh', u'Julie Christie', u'Dere...
# 157       238  [u'Clark Gable', u'Vivien Leigh', u'Thomas Mit...
# 78        229  [u'Robert De Niro', u'James Woods', u'Elizabet...
# 142       224  [u'Aamir Khan', u'Gracy Singh', u'Rachel Shell...
# 445       220  [u'Charlton Heston', u'Yul Brynner', u'Anne Ba...

# %%
movies=pd.read_csv('http://bit.ly//imdbratings')
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies.shape
# Out:
# (979, 6)

# %%
booleans=[]
for length in movies.duration:
    if length>=200:
        booleans.append(True)
    else:
        booleans.append(False)

# %%
len(booleans)
# Out:
# 979

# %%
booleans[0:10]
# Out:
# [False, False, True, False, False, False, False, True, False, False]

# %%
ser=pd.Series(booleans)
ser.head()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# dtype: bool

# %%
movies[ser].head()
# Out:
#     star_rating                                          title content_rating  \
# 2           9.1                         The Godfather: Part II              R
# 7           8.9  The Lord of the Rings: The Return of the King          PG-13
# 17          8.7                                  Seven Samurai        UNRATED
# 78          8.4                    Once Upon a Time in America              R
# 85          8.4                             Lawrence of Arabia             PG
#
#         genre  duration                                        actors_list
# 2       Crime       200  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 7   Adventure       201  [u'Elijah Wood', u'Viggo Mortensen', u'Ian McK...
# 17      Drama       207  [u'Toshir\xf4 Mifune', u'Takashi Shimura', u'K...
# 78      Crime       229  [u'Robert De Niro', u'James Woods', u'Elizabet...
# 85  Adventure       216  [u"Peter O'Toole", u'Alec Guinness', u'Anthony...

# %%
ser=movies.duration>=200
movies[ser].head()
# Out:
#     star_rating                                          title content_rating  \
# 2           9.1                         The Godfather: Part II              R
# 7           8.9  The Lord of the Rings: The Return of the King          PG-13
# 17          8.7                                  Seven Samurai        UNRATED
# 78          8.4                    Once Upon a Time in America              R
# 85          8.4                             Lawrence of Arabia             PG
#
#         genre  duration                                        actors_list
# 2       Crime       200  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 7   Adventure       201  [u'Elijah Wood', u'Viggo Mortensen', u'Ian McK...
# 17      Drama       207  [u'Toshir\xf4 Mifune', u'Takashi Shimura', u'K...
# 78      Crime       229  [u'Robert De Niro', u'James Woods', u'Elizabet...
# 85  Adventure       216  [u"Peter O'Toole", u'Alec Guinness', u'Anthony...

# %%
movies[movies.duration>=200].head()
# Out:
#     star_rating                                          title content_rating  \
# 2           9.1                         The Godfather: Part II              R
# 7           8.9  The Lord of the Rings: The Return of the King          PG-13
# 17          8.7                                  Seven Samurai        UNRATED
# 78          8.4                    Once Upon a Time in America              R
# 85          8.4                             Lawrence of Arabia             PG
#
#         genre  duration                                        actors_list
# 2       Crime       200  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 7   Adventure       201  [u'Elijah Wood', u'Viggo Mortensen', u'Ian McK...
# 17      Drama       207  [u'Toshir\xf4 Mifune', u'Takashi Shimura', u'K...
# 78      Crime       229  [u'Robert De Niro', u'James Woods', u'Elizabet...
# 85  Adventure       216  [u"Peter O'Toole", u'Alec Guinness', u'Anthony...

# %%
m1=movies[movies.duration>200].genre
pd.DataFrame(m1)
# Out:
#          genre
# 7    Adventure
# 17       Drama
# 78       Crime
# 85   Adventure
# 142  Adventure
# 157      Drama
# 204  Adventure
# 445  Adventure
# 476      Drama
# 630  Biography
# 767     Action

# %%
movies[(movies.duration>=200)&(movies.genre=='Drama')]
# Out:
#      star_rating               title content_rating  genre  duration  \
# 17           8.7       Seven Samurai        UNRATED  Drama       207
# 157          8.2  Gone with the Wind              G  Drama       238
# 476          7.8              Hamlet          PG-13  Drama       242
#
#                                            actors_list
# 17   [u'Toshir\xf4 Mifune', u'Takashi Shimura', u'K...
# 157  [u'Clark Gable', u'Vivien Leigh', u'Thomas Mit...
# 476  [u'Kenneth Branagh', u'Julie Christie', u'Dere...

# %%
movies[(movies.genre=='Crime')|(movies.genre=='Drama')|(movies.genre=='Action')].head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies[movies.genre.isin(['Crime','Drama','Action'])].head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
drinks=pd.read_csv('http://bit.ly//drinksbycountry')
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks.mean(numeric_only=True)
# Out:
# beer_servings                   106.160622
# spirit_servings                  80.994819
# wine_servings                    49.450777
# total_litres_of_pure_alcohol      4.717098
# dtype: float64

# %%
drinks['beer_servings'].mean()
# Out:
# np.float64(106.16062176165804)

# %%
drinks.mean(axis=1,numeric_only=True).head()
# Out:
# 0      0.000
# 1     69.975
# 2      9.925
# 3    176.850
# 4     81.225
# dtype: float64

# %%
drinks.mean(axis='columns',numeric_only=True).head()
# Out:
# 0      0.000
# 1     69.975
# 2      9.925
# 3    176.850
# 4     81.225
# dtype: float64

# %%
drinks.mean(axis='rows',numeric_only=True).head()
# Out:
# beer_servings                   106.160622
# spirit_servings                  80.994819
# wine_servings                    49.450777
# total_litres_of_pure_alcohol      4.717098
# dtype: float64

# %%
drinks.mean(axis='index',numeric_only=True).head()
# Out:
# beer_servings                   106.160622
# spirit_servings                  80.994819
# wine_servings                    49.450777
# total_litres_of_pure_alcohol      4.717098
# dtype: float64

# %%
drinks.dtypes
# Out:
# country                          object
# beer_servings                     int64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %%
drinks['beer_servings']=drinks.beer_servings.astype(float)
drinks.dtypes
# Out:
# country                          object
# beer_servings                   float64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %%
drinks[drinks.continent=='Africa'].beer_servings.mean()
# Out:
# np.float64(61.471698113207545)

# %%
drinks[drinks.continent=='Africa'].mean(axis=0,numeric_only=True)
# Out:
# beer_servings                   61.471698
# spirit_servings                 16.339623
# wine_servings                   16.264151
# total_litres_of_pure_alcohol     3.007547
# dtype: float64

# %%
drinks.groupby('continent').beer_servings.mean()
# Out:
# continent
# Africa            61.471698
# Asia              37.045455
# Europe           193.777778
# North America    145.434783
# Oceania           89.687500
# South America    175.083333
# Name: beer_servings, dtype: float64

# %%
drinks.groupby('continent').beer_servings.describe()
# Out:
#                count        mean        std   min     25%    50%     75%  \
# continent
# Africa          53.0   61.471698  80.557816   0.0   15.00   32.0   76.00
# Asia            44.0   37.045455  49.469725   0.0    4.25   17.5   60.50
# Europe          45.0  193.777778  99.631569   0.0  127.00  219.0  270.00
# North America   23.0  145.434783  79.621163   1.0   80.00  143.0  198.00
# Oceania         16.0   89.687500  96.641412   0.0   21.00   52.5  125.75
# South America   12.0  175.083333  65.242845  93.0  129.50  162.5  198.00
#
#                  max
# continent
# Africa         376.0
# Asia           247.0
# Europe         361.0
# North America  285.0
# Oceania        306.0
# South America  333.0

# %%
drinks.groupby('continent').beer_servings.agg(['count','max','min'])
# Out:
#                count    max   min
# continent
# Africa            53  376.0   0.0
# Asia              44  247.0   0.0
# Europe            45  361.0   0.0
# North America     23  285.0   1.0
# Oceania           16  306.0   0.0
# South America     12  333.0  93.0

# %%
import numpy as np
import pandas as pd

# %%
data_one={'A':['A0','A1','A2','A3'],'B':['B0','B1','B2','B3']}
data_two={'C':['C0','C1','C2','C3'],'D':['D0','D1','D2','D3']}
one=pd.DataFrame(data_one)
two=pd.DataFrame(data_two)

# %%
one
# Out:
#     A   B
# 0  A0  B0
# 1  A1  B1
# 2  A2  B2
# 3  A3  B3

# %%
two
# Out:
#     C   D
# 0  C0  D0
# 1  C1  D1
# 2  C2  D2
# 3  C3  D3

# %%
axis0=pd.concat([one,two],axis=0)
axis0
# Out:
#      A    B    C    D
# 0   A0   B0  NaN  NaN
# 1   A1   B1  NaN  NaN
# 2   A2   B2  NaN  NaN
# 3   A3   B3  NaN  NaN
# 0  NaN  NaN   C0   D0
# 1  NaN  NaN   C1   D1
# 2  NaN  NaN   C2   D2
# 3  NaN  NaN   C3   D3

# %%
axis1=pd.concat([one,two],axis=1)
axis1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
two.columns=one.columns

# %%
two.columns
# Out:
# Index(['A', 'B'], dtype='object')

# %%
two
# Out:
#     A   B
# 0  C0  D0
# 1  C1  D1
# 2  C2  D2
# 3  C3  D3

# %%
pd.concat([one,two],axis=0)
# Out:
#     A   B
# 0  A0  B0
# 1  A1  B1
# 2  A2  B2
# 3  A3  B3
# 0  C0  D0
# 1  C1  D1
# 2  C2  D2
# 3  C3  D3

# %%
registrations=pd.DataFrame({'reg_id':[1,2,3,4],'name':['abc','def','lmn','xyz']})
logins=pd.DataFrame({'log_id':[1,2,3,4],'name':['123','abc','789','xyz']})

# %%
registrations
# Out:
#    reg_id name
# 0       1  abc
# 1       2  def
# 2       3  lmn
# 3       4  xyz

# %%
logins
# Out:
#    log_id name
# 0       1  123
# 1       2  abc
# 2       3  789
# 3       4  xyz

# %%
pd.merge(registrations,logins,how='inner',on='name')
# Out:
#    reg_id name  log_id
# 0       1  abc       2
# 1       4  xyz       4

# %%
pd.merge(registrations,logins,how='inner')
# Out:
#    reg_id name  log_id
# 0       1  abc       2
# 1       4  xyz       4

# %%
pd.merge(registrations,logins,how='left')
# Out:
#    reg_id name  log_id
# 0       1  abc     2.0
# 1       2  def     NaN
# 2       3  lmn     NaN
# 3       4  xyz     4.0

# %%
pd.merge(registrations,logins,how='right')
# Out:
#    reg_id name  log_id
# 0     NaN  123       1
# 1     1.0  abc       2
# 2     NaN  789       3
# 3     4.0  xyz       4

# %%
pd.merge(registrations,logins,how='outer')
# Out:
#    reg_id name  log_id
# 0     NaN  123     1.0
# 1     NaN  789     3.0
# 2     1.0  abc     2.0
# 3     2.0  def     NaN
# 4     3.0  lmn     NaN
# 5     4.0  xyz     4.0

# %%
import pandas as pd
ufo=pd.read_csv('http://bit.ly//uforeports')
#ufo['location'],ufo['timessss']=[ufo.city+'**'+ufo.State,ufo['Time']]

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo['Location'],ufo['timessss']=[ufo.City+'**'+ufo.State,ufo['Time']]

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time  \
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00
#
#                    Location         timessss
# 0                Ithaca**NY   6/1/1930 22:00
# 1           Willingboro**NJ  6/30/1930 20:00
# 2               Holyoke**CO  2/15/1931 14:00
# 3               Abilene**KS   6/1/1931 13:00
# 4  New York Worlds Fair**NY  4/18/1933 19:00

# %%
ufo=pd.read_csv('http://bit.ly//uforeports')
ufo.tail()
# Out:
#               City Colors Reported Shape Reported State              Time
# 18236   Grant Park             NaN       TRIANGLE    IL  12/31/2000 23:00
# 18237  Spirit Lake             NaN           DISK    IA  12/31/2000 23:00
# 18238  Eagle River             NaN            NaN    WI  12/31/2000 23:45
# 18239  Eagle River             RED          LIGHT    WI  12/31/2000 23:45
# 18240         Ybor             NaN           OVAL    FL  12/31/2000 23:59

# %%
ufo.isnull().tail()
# Out:
#         City  Colors Reported  Shape Reported  State   Time
# 18236  False             True           False  False  False
# 18237  False             True           False  False  False
# 18238  False             True            True  False  False
# 18239  False            False           False  False  False
# 18240  False             True           False  False  False

# %%
ufo.notnull().tail()
# Out:
#        City  Colors Reported  Shape Reported  State  Time
# 18236  True            False            True   True  True
# 18237  True            False            True   True  True
# 18238  True            False           False   True  True
# 18239  True             True            True   True  True
# 18240  True            False            True   True  True

# %%
ufo.isnull().sum()
# Out:
# City                  26
# Colors Reported    15359
# Shape Reported      2644
# State                  0
# Time                   0
# dtype: int64

# %%
ufo.shape
# Out:
# (18241, 5)

# %%
ufo.dropna(how='any').shape
# Out:
# (2486, 5)

# %%
ufo.dropna(how='all').shape
# Out:
# (18241, 5)

# %%
ufo.dropna(subset=['City','Shape Reported'],how='all').shape
# Out:
# (18237, 5)

# %%
ufo['Shape Reported'].value_counts(dropna=False).head()
# Out:
# Shape Reported
# LIGHT       2803
# NaN         2644
# DISK        2122
# TRIANGLE    1889
# OTHER       1402
# Name: count, dtype: int64

# %%
ufo['Shape Reported'].fillna(value='Besant',inplace=True)
ufo['Shape Reported'].value_counts().head()
# Out:
# Shape Reported
# LIGHT       2803
# Besant      2644
# DISK        2122
# TRIANGLE    1889
# OTHER       1402
# Name: count, dtype: int64

# %%
orders=pd.read_table('http://bit.ly/chiporders')
orders.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
orders.item_name.str.upper().head()
# Out:
# 0             CHIPS AND FRESH TOMATO SALSA
# 1                                     IZZE
# 2                         NANTUCKET NECTAR
# 3    CHIPS AND TOMATILLO-GREEN CHILI SALSA
# 4                             CHICKEN BOWL
# Name: item_name, dtype: object

# %%
orders.item_name.str.contains('Chicken').head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# Name: item_name, dtype: bool

# %%
orders[orders.item_name.str.contains('Chicken')].head()
# Out:
#     order_id  quantity             item_name  \
# 4          2         2          Chicken Bowl
# 5          3         1          Chicken Bowl
# 11         6         1  Chicken Crispy Tacos
# 12         6         1    Chicken Soft Tacos
# 13         7         1          Chicken Bowl
#
#                                    choice_description item_price
# 4   [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# 5   [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98
# 11  [Roasted Chili Corn Salsa, [Fajita Vegetables,...     $8.75
# 12  [Roasted Chili Corn Salsa, [Rice, Black Beans,...     $8.75
# 13  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...    $11.25

# %%
orders.choice_description.str.replace('[','').str.replace(']','').head()
# Out:
# 0                                                  NaN
# 1                                           Clementine
# 2                                                Apple
# 3                                                  NaN
# 4    Tomatillo-Red Chili Salsa (Hot), Black Beans, ...
# Name: choice_description, dtype: object
